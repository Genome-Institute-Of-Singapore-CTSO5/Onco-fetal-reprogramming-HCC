# %%
import numpy as np
import pandas as pd
import scanpy.api as sc
import matplotlib.pyplot as plt

sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=100, color_map='viridis')# verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()

#import os
#os.chdir('C:/Users/seowjjw/Dropbox/Liver_Paper/Liver10X_76k_Fig2/')
#os.chdir('/Users/justineseowjiawen/Dropbox/covid figures/')

#sc.pl.rank_genes_groups_dotplot(adata, n_genes=2, standard_scale='var', dot_max=0.9, dot_min=0.3)
# Out:
# scanpy==1.4.6 anndata==0.7.1 umap==0.3.10 numpy==1.15.4 scipy==1.4.1 pandas==0.23.4 scikit-learn==0.22.1 statsmodels==0.11.0rc1 python-igraph==0.7.1 louvain==0.6.1

# %% [markdown]
# #

# %% [markdown]
# # COVID HCC

# %%
adata = sc.read("/Users/justineseowjiawen/Dropbox/Liver_Paper/Liver10X_76k_Fig1/data/Liver10X_73k.h5ad")

genes = ['IL7R', 'GNLY', 'SPRY1', 'PLVAP', 'CD8A', 'CD8B', 'CAV1', 'SPINK1', 'ALB', 'LYZ', 'CD7', 'NKG7', 'C1QA',
         'CD68', 'APOC3', 'FXYD1', 'TIGIT', 'BATF', 'MYL9', 'ACTA2', 'SERPINA1', 'CYP2E1', 'PRF1', 'CYP2A7', 'CYP4F3',
         'SPARC', 'PLVAP', 'MZB1', 'CD79A', 'CD74', 'CD83', 'MLXIPL', 'ORM1', 'TTR', 'STMN1', 'HMGB2', 'KRT18', 'KRT19',
         'C3', 'HPX', 'FCN3', 'AKAP12', 'TFF3', 'FABP4', 'KIT']

sc.pl.dotplot(adata, genes, groupby='louvain', dot_max=0.8, dot_min=0.2, standard_scale='var',
              color_map='Reds', save='_HCC_dotplot.pdf')
# Out:
# WARNING: saving figure to file figures_Liv73k/dotplot_HCC_dotplot.pdf
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[15.749999999999998, 0, 0.2, 0.5, 0.25])

# %% [markdown]
# #

# %% [markdown]
# #  HCC

# %%
sc.settings.figdir = './figures_Liv73k/'
adata = sc.read("./data/Liver10X_73k.h5ad")

genes = ['IL7R', 'GNLY', 'SPRY1', 'PLVAP', 'CD8A', 'CD8B', 'CAV1', 'SPINK1', 'ALB', 'LYZ', 'CD7', 'NKG7', 'C1QA',
         'CD68', 'APOC3', 'FXYD1', 'TIGIT', 'BATF', 'MYL9', 'ACTA2', 'SERPINA1', 'CYP2E1', 'PRF1', 'CYP2A7', 'CYP4F3',
         'SPARC', 'PLVAP', 'MZB1', 'CD79A', 'CD74', 'CD83', 'MLXIPL', 'ORM1', 'TTR', 'STMN1', 'HMGB2', 'CD24', 'KRT19',
         'C3', 'HPX', 'FCN3', 'AKAP12', 'TFF3', 'FABP4', 'KIT']

genes = ['IL7R','GNLY','GZMB','NKG7','SPRY1', 'PLVAP','DONSON', 'CD8A', 'CD8B','CCL5','CCL4','DNAJB1','HSPA1B','HSPA1A',
         'TM4SF1','CAV1','SPINK1','ALB','RARRES2','LYZ','HLA-DRA','KLRB1','CD7','TYROBP','C1QA','APOA1','TRAC','TIGIT',
         'BATF','TAGLN','CALD1','MYL9','APOA2','FABP1','HBB','HBA2','APOC3','SPARC','PLVAP','MS4A1','MLXIPL',
         'APOC1','STMN1','HMGB2','ANXA4','C3','IFI27','RBP4','FCN3','DNASE1L3','CRHBP','TFF3','TFPI','TPSB2',
         'TPSAB1','HPGDS']

sc.pl.dotplot(adata, genes, groupby='louvain', dot_max=0.8, dot_min=0.2, standard_scale='var',
              color_map='Reds')

# %% [markdown]
# #

# %% [markdown]
# # myewob

# %%
sc.settings.figdir = ''
adata = sc.read("/Users/justineseowjiawen/Dropbox/Liver_Paper/HCC_F1F2/data/HCCmyewoF.h5ad")

gene = ['CD1C','FCER1A','CLEC10A','C1QB','FOLR2','S100A8','MT1G','APOC3','ORM1','RNASE1','MRC1','CD163',
        'MS4A1','SPP1','IDO1','LGALS2','JCHAIN','IGKC','AIF1','LYZ','NOTCH2']
sc.pl.dotplot(adata, gene, groupby='louvain', dot_max=0.7, standard_scale='var', dot_min=0.3,
              color_map='Reds')#,save='_myewob.pdf')
# Out:
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[7.35, 0, 0.2, 0.5, 0.25])

# %% [markdown]
# #

# %% [markdown]
# # myewoDC3

# %%
sc.settings.figdir = '/Users/justineseowjiawen/Downloads/'
adata = sc.read("/Users/justineseowjiawen/Dropbox/Liver_Paper/HCC_F1F2/data/HCCmyewoF.h5ad")

gene = ['CD1C','CLEC10A','FOLR2','CD163','MRC1','HES1','S100A8','SPP1','LGALS2','MT1G','MT2A','JCHAIN','IGKC']
sc.pl.dotplot(adata, gene, groupby='louvain', dot_max=0.6, dot_min=0.2, standard_scale='var',
              color_map='Reds',save='_myewob.pdf')
# Out:
# WARNING: saving figure to file /Users/justineseowjiawen/Downloads/dotplot_myewob.pdf
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[4.55, 0, 0.2, 0.5, 0.25])

# %% [markdown]
# #

# %% [markdown]
# # tcells

# %%
sc.settings.figdir = './paper_figures1/tcells/'
adata = sc.read("./data/tcells.h5ad")

marker_genes = ['CD69','GZMB','GZMK','CCR7','CRTAM','IFNG','DONSON','XCL2','AC133644.2','TIGIT', 'TNFSF14','LTB','C1orf56',
                'BATF','AC002331.1','B3GNT7','CMC1','CD8A', 'CD8B','CXCL13','MAPK13','RP11-386I14.4','JUNB','STMN1','HBB',
                'HBA2']

sc.pl.dotplot(adata, marker_genes, groupby='louvain', dot_max=0.7, dot_min=0.3, standard_scale='var', color_map='Reds',save='_immune.pdf')

# %% [markdown]
# #

# %% [markdown]
# # NK

# %%
sc.settings.figdir = './paper_figures1/NK/'
adata = sc.read("./data/NK_recluster.h5ad")

gene = ['KLRC2','KLRC1','CLIC3','MYOM2','KRT86','NEAT1','S100B','KRT81','BCO2','KIR2DL1']
sc.pl.dotplot(adata, gene, groupby='louvain', dot_min=0.3, standard_scale='var', color_map='Reds')#,save='_NK.pdf')

# %% [markdown]
# #

# %% [markdown]
# # hepa

# %%
sc.settings.figdir = './paper_figures1/hepa/'
adata = sc.read("./data/hepa.h5ad")

marker_genes = ['CYP2E1','IGKC','IGLC2','GAPDH','FXYD1','RPS29','TMSB4X','S100A10','H3F3A','NDUFA4L2','NEAT1','MLXIPL',
                'CYP2A7','SLC22A7','SAA1','APOC2','APOE','HULC','KRT19','S100A6','DEFB1','C4BPA','SERPINC1','FABP1','ALB']

sc.pl.dotplot(adata, marker_genes, groupby='louvain', dot_max=0.7, dot_min=0.3, standard_scale='var', save='_hepa.pdf')

# %% [markdown]
# #

# %% [markdown]
# # fibro

# %%
sc.settings.figdir = './paper_figures1/fibro/'
adata = sc.read("./data/fibro.h5ad")

genes = ['MYH11','MYL9','TAGLN','ACTA2','MFAP4','COL4A2','MT1M','MT1A','LUM','VCAN','RGS5','CDH19',
         'MPZ','RAMP2','JAG1']
sc.pl.dotplot(adata, genes, groupby='louvain', color_map='Reds', dot_max=0.7, dot_min=0.3, standard_scale='var', save='_fibro.pdf')

# %% [markdown]
# #

# %% [markdown]
# # endo

# %%
sc.settings.figdir = './paper_figures1/endo/'
adata = sc.read("./data/endo_73k.h5ad")

marker_genes = ['PLPP3','FCN3','AC090498.1','CD9','MT2A','SPRY1','PLVAP','SLC9A3R2','TIMP1','IGFBP3', 'NOTCH4','DLL4',
                'JAG1','ACKR1','VWF','TFF3','PROX1']

marker_genes = ['PLVAP','AC090498.1','FCN3','APOA2','PLPP3','HLA-DRA','ADAMTS1','SERPINE2','CRHBP',
                'IGFBP3','FBLN5','NOTCH4','VWF','ACKR1','TFF3','CCL21','PROX1']

marker_genes = ['SRP14','CD9','SPRY1','PLVAP','FCN3','NOTCH4','THY1','STC1','SERPINE2','IGFBP3','FBLN5','MECOM',
                'CLDN5','GJA4','ICAM2','DLL4','JAG1','JAG2','VWF','ACKR1','FABP5','TFF3','CCL21','PROX1']

sc.pl.dotplot(adata, marker_genes, groupby='louvain', color_map='Reds', dot_max=0.7, dot_min=0.1,
              standard_scale='var')#, save='_endo.pdf')
